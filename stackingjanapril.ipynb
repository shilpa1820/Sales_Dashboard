# %% [markdown]
# <a href="https://colab.research.google.com/github/shilpa1820/Sales_Dashboard/blob/main/stackingjanapril.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
april= pd.read_csv("/content/aprilsales.csv")
jan=pd.read_csv("/content/jansales.csv")

# %%
april.head()
# Out:
#    Unnamed: 0  Order ID                     Product  Quantity Ordered  \
# 0           0    176558        USB-C Charging Cable                 2
# 1           2    176559  Bose SoundSport Headphones                 1
# 2           3    176560                Google Phone                 1
# 3           4    176560            Wired Headphones                 1
# 4           5    176561            Wired Headphones                 1
#
#    Price Each        Order Date                      Purchase Address  \
# 0       11.95    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1       99.99  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2      600.00  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3       11.99  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4       11.99    04/30/19 09:27     333 8th St, Los Angeles, CA 90001
#
#    postal_code
# 0        75001
# 1         2215
# 2        90001
# 3        90001
# 4        90001

# %%
jan.head()
# Out:
#    Unnamed: 0  Order ID                   Product  Quantity Ordered  \
# 0           0    141234                    iPhone                 1
# 1           1    141235  Lightning Charging Cable                 1
# 2           2    141236          Wired Headphones                 2
# 3           3    141237          27in FHD Monitor                 1
# 4           4    141238          Wired Headphones                 1
#
#    Price Each      Order Date                       Purchase Address  \
# 0      700.00  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1       14.95  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2       11.99  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3      149.99  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4       11.99  01/25/19 11:59          387 10th St, Austin, TX 73301
#
#    postal_code
# 0         2215
# 1        97035
# 2        94016
# 3        90001
# 4        73301

# %%
sales = pd.concat([april, jan], ignore_index=True, axis=0)

# %%
sales.head()
# Out:
#    Unnamed: 0  Order ID                     Product  Quantity Ordered  \
# 0           0    176558        USB-C Charging Cable                 2
# 1           2    176559  Bose SoundSport Headphones                 1
# 2           3    176560                Google Phone                 1
# 3           4    176560            Wired Headphones                 1
# 4           5    176561            Wired Headphones                 1
#
#    Price Each        Order Date                      Purchase Address  \
# 0       11.95    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1       99.99  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2      600.00  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3       11.99  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4       11.99    04/30/19 09:27     333 8th St, Los Angeles, CA 90001
#
#    postal_code
# 0        75001
# 1         2215
# 2        90001
# 3        90001
# 4        90001

# %%
sales=sales.drop(["Unnamed: 0"],axis=1)

# %%
sales.to_csv("aprilsaless.csv")
